-- %%
import Text.Megaparsec
import Text.Megaparsec.Char
import Data.Char
import qualified Data.Text as T
import Control.Monad.Bayes.Class
import Control.Monad.Bayes.Sampler
import Control.Monad.Bayes.Weighted
import Control.Monad.Bayes.Population
import Control.Monad.Bayes.Inference.SMC
import Control.Monad.Trans (lift)
import Control.Monad (join, replicateM)
import Data.Void
import Text.Pretty.Simple
:e OverloadedStrings
:e FlexibleContexts
:e GADTs
:e LambdaCase

-- %%
noise = \case
    'g' -> lift $ uniformD ['g','h']
    'h' -> return 'h'

parser =  some (do
    -- x <- lookAhead "h"
    true <- fmap head $ lift $ uniformD ["g", "h"]
    predicted <- noise true
    -- predicted <- join $ lift $ uniformD ["a", "b"]
    observed <- lookAhead (char 'g' <|> char 'h')
    lift $ condition $ predicted == observed
    char observed
    -- y <- "h"
    -- "h"
    -- y <- lookAhead "h"
    -- return (,x)
    -- return (observed, y)
    return (true)) <* eof

errorBundlePretty' :: (TraversableStream s, VisualStream s) => ParseErrorBundle s Void -> String 
errorBundlePretty' = errorBundlePretty

-- foo :: MonadInfer m => m T.Text

foo = (either (T.pack . errorBundlePretty' ) (T.pack . show) ) <$> runParserT parser "" "hh"
-- Out:
-- Line 18: Redundant bracket
-- Found:
-- (true)
-- Why not:
-- trueLine 25: Redundant bracket
-- Found:
-- (either (T.pack . errorBundlePretty') (T.pack . show))
--   <$> runParserT parser "" "hh"
-- Why not:
-- either (T.pack . errorBundlePretty') (T.pack . show)
--   <$> runParserT parser "" "hh"

-- %%
x <- sampleIO $ runPopulation $ smcMultinomial 2 10 $ foo
pPrint x
-- Out:
-- [
--     ( ""hg""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hg""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ,
--     ( ""hh""
--     , 4.799999999999996 e- 2
--     )
-- ]
