-- %%
:e OverloadedStrings
:l ../models/LDA.hs

-- %%
runLDA
-- Out:
-- ( fromList
--     [
--         ( "topic1"
--         ,
--             [
--                 ( "bear"
--                 , 0.34365781935415857
--                 )
--             ,
--                 ( "wolf"
--                 , 0.2556245339526619
--                 )
--             ,
--                 ( "python"
--                 , 0.24562951016031953
--                 )
--             ,
--                 ( "prolog"
--                 , 0.15508813653285997
--                 )
--             ]
--         )
--     ,
--         ( "topic2"
--         ,
--             [
--                 ( "bear"
--                 , 3.910578485111217 e- 2
--                 )
--             ,
--                 ( "wolf"
--                 , 0.4304465204440071
--                 )
--             ,
--                 ( "python"
--                 , 0.1486640274645592
--                 )
--             ,
--                 ( "prolog"
--                 , 0.3817836672403215
--                 )
-- ...
